# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)

# %%
import os
import requests
from time import sleep
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Set up the folder to store images
folder_name = "restored_images1"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# API details
api_key = "hylepsentrog"  # Replace with your actual API key
base_url = "https://api.europeana.eu/record/v2/search.json"

# Define the query parameters
params = {
    "query": "places",
    "media": "true",  # Ensures that only records with media (images) are returned
    "rows": 100,  # Number of results per page (adjust as needed)
    "start": 1,   # Start index for pagination
    "wskey": api_key  # Your API key
}

# Function to download an image
def download_image(url, image_name):
    if isinstance(url, list):
        url = url[0]  # Extract the string from the list if needed

    session = requests.Session()
    retries = Retry(total=5, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
    session.mount('https://', HTTPAdapter(max_retries=retries))
    session.mount('http://', HTTPAdapter(max_retries=retries))

    try:
        # Disable SSL verification if needed
        img_response = session.get(url, verify=False)
        if img_response.status_code == 200:
            with open(os.path.join(folder_name, image_name), 'wb') as img_file:
                img_file.write(img_response.content)
            print(f"Downloaded {image_name}")
        elif img_response.status_code == 404:
            print(f"Image not found (404) for {image_name}")
        else:
            print(f"Failed to download {image_name}, status code: {img_response.status_code}")
    except requests.exceptions.SSLError as e:
        print(f"SSL error occurred while downloading {image_name}: {e}")
    except requests.exceptions.RequestException as e:
        print(f"Request error occurred while downloading {image_name}: {e}")

# Fetch and process the data from the API
image_count = 277
while True:
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])

        # Download each image
        for item in items:
            if 'edmIsShownBy' in item:
                img_url = item['edmIsShownBy']
                download_image(img_url, f"R{image_count}.jpg")
                image_count += 1

        # Check if there are more results to fetch
        if len(items) < params['rows']:
            break  # Exit the loop if fewer items are returned than requested (end of results)
        else:
            params['start'] += params['rows']  # Move to the next page
    else:
        print(f"Failed to retrieve data from the API. Status code: {response.status_code}")
        break
# Out:
# Failed to retrieve data from the API. Status code: 400

# %% [markdown]
# another api key for places provided by the Swedish Open Cultural Heritage

# %%
import os
import requests
from urllib.parse import urlparse, parse_qs
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Set up the folder to store images on your local machine
folder_name = "restored_images"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Parse the provided URL to extract the base URL and query parameters
api_url = "https://api.europeana.eu/record/search.json?wskey=hylepsentrog&qf=collection%3Aphotography&qf=TYPE%3A%22IMAGE%22&qf=contentTier%3A%224%22&qf=PROVIDER%3A%22Swedish+Open+Cultural+Heritage%22&query=places&reusability=open&profile=facets&rows=0&facet=PROVIDER&f.PROVIDER.facet.limit=125000&start=1"

# Parse the URL
parsed_url = urlparse(api_url)
base_url = f"{parsed_url.scheme}://{parsed_url.netloc}{parsed_url.path}"
params = parse_qs(parsed_url.query)

# Convert the list of query values to a single value where appropriate
for key in params:
    if isinstance(params[key], list) and len(params[key]) == 1:
        params[key] = params[key][0]

# Set rows to a specific value to get actual data (instead of 0)
params['rows'] = 100  # Adjust this as needed

# Function to download an image
def download_image(url, image_name):
    if isinstance(url, list):
        url = url[0]  # Extract the string from the list if needed

    session = requests.Session()
    retries = Retry(total=5, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
    session.mount('https://', HTTPAdapter(max_retries=retries))
    session.mount('http://', HTTPAdapter(max_retries=retries))

    try:
        # Disable SSL verification if needed
        img_response = session.get(url, verify=False)
        if img_response.status_code == 200:
            # Save the image to the local "restored_images" folder
            with open(os.path.join(folder_name, image_name), 'wb') as img_file:
                img_file.write(img_response.content)
            print(f"Downloaded {image_name}")
        elif img_response.status_code == 404:
            print(f"Image not found (404) for {image_name}")
        else:
            print(f"Failed to download {image_name}, status code: {img_response.status_code}")
    except requests.exceptions.SSLError as e:
        print(f"SSL error occurred while downloading {image_name}: {e}")
    except requests.exceptions.RequestException as e:
        print(f"Request error occurred while downloading {image_name}: {e}")

# Fetch and process the data from the API
image_count = 0
while True:
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])

        # Download each image
        for item in items:
            if 'edmIsShownBy' in item:
                img_url = item['edmIsShownBy']
                download_image(img_url, f"R{image_count}.jpg")
                image_count += 1

        # Check if there are more results to fetch
        if len(items) < int(params['rows']):
            break  # Exit the loop if fewer items are returned than requested (end of results)
        else:
            params['start'] = int(params['start']) + int(params['rows'])  # Move to the next page
    else:
        print(f"Failed to retrieve data from the API. Status code: {response.status_code}")
        break
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R0.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R1.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R2.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R3.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R4.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R5.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R6.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R7.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R8.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R9.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R10.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R11.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R12.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R13.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R14.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R15.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R16.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R17.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R18.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R19.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R20.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R21.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R22.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R23.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R24.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R25.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R26.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R27.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R28.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R29.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R30.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R31.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R32.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R33.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R34.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R35.jpg
# Downloaded R36.jpg
# Downloaded R37.jpg
# Downloaded R38.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R39.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R40.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R41.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R42.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R43.jpg
# Downloaded R44.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R45.jpg
# Downloaded R46.jpg
# Downloaded R47.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R48.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R49.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R50.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R51.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R52.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R53.jpg
# Downloaded R54.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R55.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R56.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R57.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R58.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R59.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R60.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R61.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R62.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R63.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R64.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R65.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R66.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R67.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R68.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R69.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R70.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R71.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R72.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R73.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R74.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R75.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R76.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R77.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R78.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R79.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R80.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R81.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R82.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R83.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R84.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R85.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R86.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R87.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R88.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R89.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R90.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R91.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R92.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R93.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R94.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R95.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R96.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R97.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R98.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R99.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R100.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R101.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R102.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R103.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R104.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R105.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R106.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R107.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R108.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R109.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R110.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R111.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R112.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R113.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R114.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R115.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R116.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R117.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R118.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R119.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R120.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R121.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R122.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R123.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R124.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R125.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R126.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R127.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R128.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R129.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R130.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R131.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R132.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R133.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R134.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R135.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R136.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R137.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R138.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R139.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R140.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R141.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R142.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R143.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R144.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R145.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R146.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R147.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R148.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R149.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R150.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R151.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R152.jpg
# ...
#   warnings.warn(
# Downloaded R275.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R276.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R277.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R278.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R279.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R280.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R281.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R282.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R283.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R284.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R285.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R286.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R287.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R288.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R289.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R290.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R291.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R292.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R293.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R294.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R295.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R296.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R297.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R298.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R299.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R300.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R301.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R302.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R303.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R304.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R305.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R306.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R307.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R308.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R309.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R310.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R311.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R312.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R313.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R314.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R315.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R316.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R317.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R318.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R319.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R320.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'samlingar.goteborgsstadsmuseum.se'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R321.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'samlingar.goteborgsstadsmuseum.se'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R322.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mm.dimu.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R323.jpg
# Downloaded R324.jpg
# Downloaded R325.jpg
# Downloaded R326.jpg
# Downloaded R327.jpg

# %%
# prompt: download restored_images on my machine

from google.colab import files
# !zip -r /content/restored_images.zip /content/restored_images
files.download("/content/restored_images.zip")
# Out:
#   adding: content/restored_images/ (stored 0%)
#   adding: content/restored_images/R81.jpg (deflated 2%)
#   adding: content/restored_images/R267.jpg (deflated 2%)
#   adding: content/restored_images/R246.jpg (deflated 2%)
#   adding: content/restored_images/R56.jpg (deflated 2%)
#   adding: content/restored_images/R167.jpg (deflated 2%)
#   adding: content/restored_images/R325.jpg (deflated 0%)
#   adding: content/restored_images/R69.jpg (deflated 2%)
#   adding: content/restored_images/R277.jpg (deflated 2%)
#   adding: content/restored_images/R38.jpg (deflated 1%)
#   adding: content/restored_images/R117.jpg (deflated 2%)
#   adding: content/restored_images/R15.jpg (deflated 1%)
#   adding: content/restored_images/R112.jpg (deflated 2%)
#   adding: content/restored_images/R155.jpg (deflated 2%)
#   adding: content/restored_images/R172.jpg (deflated 2%)
#   adding: content/restored_images/R302.jpg (deflated 2%)
#   adding: content/restored_images/R119.jpg (deflated 2%)
#   adding: content/restored_images/R294.jpg (deflated 2%)
#   adding: content/restored_images/R83.jpg (deflated 2%)
#   adding: content/restored_images/R25.jpg (deflated 1%)
#   adding: content/restored_images/R313.jpg (deflated 2%)
#   adding: content/restored_images/R231.jpg (deflated 4%)
#   adding: content/restored_images/R230.jpg (deflated 3%)
#   adding: content/restored_images/R52.jpg (deflated 2%)
#   adding: content/restored_images/R266.jpg (deflated 2%)
#   adding: content/restored_images/R88.jpg (deflated 2%)
#   adding: content/restored_images/R186.jpg (deflated 2%)
#   adding: content/restored_images/R192.jpg (deflated 2%)
#   adding: content/restored_images/R289.jpg (deflated 4%)
#   adding: content/restored_images/R191.jpg (deflated 6%)
#   adding: content/restored_images/R7.jpg (deflated 0%)
#   adding: content/restored_images/R158.jpg (deflated 2%)
#   adding: content/restored_images/R216.jpg (deflated 2%)
#   adding: content/restored_images/R78.jpg (deflated 2%)
#   adding: content/restored_images/R10.jpg (deflated 2%)
#   adding: content/restored_images/R293.jpg (deflated 3%)
#   adding: content/restored_images/R213.jpg (deflated 2%)
#   adding: content/restored_images/R183.jpg (deflated 2%)
#   adding: content/restored_images/R3.jpg (deflated 1%)
#   adding: content/restored_images/R204.jpg (deflated 3%)
#   adding: content/restored_images/R14.jpg (deflated 2%)
#   adding: content/restored_images/R128.jpg (deflated 2%)
#   adding: content/restored_images/R205.jpg (deflated 3%)
#   adding: content/restored_images/R281.jpg (deflated 2%)
#   adding: content/restored_images/R220.jpg (deflated 2%)
#   adding: content/restored_images/R290.jpg (deflated 3%)
#   adding: content/restored_images/R242.jpg (deflated 2%)
#   adding: content/restored_images/R93.jpg (deflated 2%)
#   adding: content/restored_images/R278.jpg (deflated 2%)
#   adding: content/restored_images/R102.jpg (deflated 3%)
#   adding: content/restored_images/R270.jpg (deflated 2%)
#   adding: content/restored_images/R184.jpg (deflated 2%)
#   adding: content/restored_images/R194.jpg (deflated 2%)
#   adding: content/restored_images/R276.jpg (deflated 2%)
#   adding: content/restored_images/R233.jpg (deflated 3%)
#   adding: content/restored_images/R40.jpg (deflated 2%)
#   adding: content/restored_images/R248.jpg (deflated 2%)
#   adding: content/restored_images/R146.jpg (deflated 2%)
#   adding: content/restored_images/R138.jpg (deflated 3%)
#   adding: content/restored_images/R55.jpg (deflated 2%)
#   adding: content/restored_images/R41.jpg (deflated 2%)
#   adding: content/restored_images/R34.jpg (deflated 0%)
#   adding: content/restored_images/R193.jpg (deflated 2%)
#   adding: content/restored_images/R26.jpg (deflated 3%)
#   adding: content/restored_images/R199.jpg (deflated 2%)
#   adding: content/restored_images/R174.jpg (deflated 2%)
#   adding: content/restored_images/R310.jpg (deflated 2%)
#   adding: content/restored_images/R286.jpg (deflated 2%)
#   adding: content/restored_images/R137.jpg (deflated 2%)
#   adding: content/restored_images/R287.jpg (deflated 2%)
#   adding: content/restored_images/R108.jpg (deflated 2%)
#   adding: content/restored_images/R22.jpg (deflated 0%)
#   adding: content/restored_images/R161.jpg (deflated 2%)
#   adding: content/restored_images/R322.jpg (deflated 1%)
#   adding: content/restored_images/R61.jpg (deflated 2%)
#   adding: content/restored_images/R58.jpg (deflated 2%)
#   adding: content/restored_images/R73.jpg (deflated 2%)
#   adding: content/restored_images/R19.jpg (deflated 2%)
#   adding: content/restored_images/R234.jpg (deflated 2%)
#   adding: content/restored_images/R151.jpg (deflated 2%)
#   adding: content/restored_images/R226.jpg (deflated 2%)
#   adding: content/restored_images/R62.jpg (deflated 2%)
#   adding: content/restored_images/R36.jpg (deflated 1%)
#   adding: content/restored_images/R122.jpg (deflated 3%)
#   adding: content/restored_images/R225.jpg (deflated 2%)
#   adding: content/restored_images/R324.jpg (deflated 0%)
#   adding: content/restored_images/R252.jpg (deflated 3%)
#   adding: content/restored_images/R243.jpg (deflated 3%)
#   adding: content/restored_images/R255.jpg (deflated 2%)
#   adding: content/restored_images/R17.jpg (deflated 1%)
#   adding: content/restored_images/R49.jpg (deflated 6%)
#   adding: content/restored_images/R144.jpg (deflated 2%)
#   adding: content/restored_images/R133.jpg (deflated 2%)
#   adding: content/restored_images/R303.jpg (deflated 2%)
#   adding: content/restored_images/R182.jpg (deflated 2%)
#   adding: content/restored_images/R20.jpg (deflated 2%)
#   adding: content/restored_images/R305.jpg (deflated 2%)
#   adding: content/restored_images/R317.jpg (deflated 3%)
#   adding: content/restored_images/R97.jpg (deflated 2%)
#   adding: content/restored_images/R298.jpg (deflated 0%)
#   adding: content/restored_images/R85.jpg (deflated 2%)
#   adding: content/restored_images/R163.jpg (deflated 2%)
#   adding: content/restored_images/R201.jpg (deflated 2%)
#   adding: content/restored_images/R57.jpg (deflated 2%)
#   adding: content/restored_images/R139.jpg (deflated 2%)
#   adding: content/restored_images/R210.jpg (deflated 2%)
#   adding: content/restored_images/R70.jpg (deflated 3%)
#   adding: content/restored_images/R292.jpg (deflated 2%)
#   adding: content/restored_images/R16.jpg (deflated 0%)
#   adding: content/restored_images/R111.jpg (deflated 2%)
#   adding: content/restored_images/R272.jpg (deflated 2%)
#   adding: content/restored_images/R24.jpg (deflated 1%)
#   adding: content/restored_images/R271.jpg (deflated 2%)
#   adding: content/restored_images/R136.jpg (deflated 2%)
#   adding: content/restored_images/R218.jpg (deflated 2%)
#   adding: content/restored_images/R263.jpg (deflated 3%)
#   adding: content/restored_images/R188.jpg (deflated 2%)
#   adding: content/restored_images/R265.jpg (deflated 3%)
#   adding: content/restored_images/R244.jpg (deflated 2%)
#   adding: content/restored_images/R196.jpg (deflated 2%)
#   adding: content/restored_images/R64.jpg (deflated 2%)
#   adding: content/restored_images/R6.jpg (deflated 0%)
#   adding: content/restored_images/R0.jpg (deflated 1%)
#   adding: content/restored_images/R159.jpg (deflated 3%)
#   adding: content/restored_images/R65.jpg (deflated 2%)
#   adding: content/restored_images/R306.jpg (deflated 2%)
#   adding: content/restored_images/R115.jpg (deflated 3%)
#   adding: content/restored_images/R275.jpg (deflated 2%)
#   adding: content/restored_images/R72.jpg (deflated 2%)
#   adding: content/restored_images/R175.jpg (deflated 2%)
#   adding: content/restored_images/R106.jpg (deflated 2%)
#   adding: content/restored_images/R116.jpg (deflated 2%)
#   adding: content/restored_images/R185.jpg (deflated 3%)
#   adding: content/restored_images/R209.jpg (deflated 2%)
#   adding: content/restored_images/R129.jpg (deflated 3%)
#   adding: content/restored_images/R264.jpg (deflated 3%)
#   adding: content/restored_images/R288.jpg (deflated 2%)
#   adding: content/restored_images/R250.jpg (deflated 3%)
#   adding: content/restored_images/R232.jpg (deflated 3%)
#   adding: content/restored_images/R89.jpg (deflated 7%)
#   adding: content/restored_images/R132.jpg (deflated 2%)
#   adding: content/restored_images/R118.jpg (deflated 2%)
#   adding: content/restored_images/R141.jpg (deflated 2%)
#   adding: content/restored_images/R295.jpg (deflated 2%)
#   adding: content/restored_images/R171.jpg (deflated 2%)
#   adding: content/restored_images/R319.jpg (deflated 3%)
#   adding: content/restored_images/R30.jpg (deflated 1%)
#   adding: content/restored_images/R227.jpg (deflated 2%)
#   adding: content/restored_images/R323.jpg (deflated 4%)
#   adding: content/restored_images/R269.jpg (deflated 1%)
#   adding: content/restored_images/R309.jpg (deflated 2%)
#   adding: content/restored_images/R280.jpg (deflated 2%)
#   adding: content/restored_images/R46.jpg (deflated 2%)
#   adding: content/restored_images/R23.jpg (deflated 1%)
#   adding: content/restored_images/R206.jpg (deflated 2%)
#   adding: content/restored_images/R60.jpg (deflated 2%)
#   adding: content/restored_images/R240.jpg (deflated 4%)
#   adding: content/restored_images/R211.jpg (deflated 3%)
#   adding: content/restored_images/R279.jpg (deflated 2%)
#   adding: content/restored_images/R318.jpg (deflated 2%)
#   adding: content/restored_images/R190.jpg (deflated 2%)
#   adding: content/restored_images/R96.jpg (deflated 2%)
#   adding: content/restored_images/R166.jpg (deflated 4%)
#   adding: content/restored_images/R235.jpg (deflated 2%)
#   adding: content/restored_images/R247.jpg (deflated 2%)
#   adding: content/restored_images/R91.jpg (deflated 2%)
#   adding: content/restored_images/R311.jpg (deflated 3%)
#   adding: content/restored_images/R180.jpg (deflated 3%)
#   adding: content/restored_images/R113.jpg (deflated 2%)
#   adding: content/restored_images/R43.jpg (deflated 3%)
#   adding: content/restored_images/R316.jpg (deflated 3%)
#   adding: content/restored_images/R154.jpg (deflated 2%)
#   adding: content/restored_images/R238.jpg (deflated 2%)
#   adding: content/restored_images/R21.jpg (deflated 1%)
#   adding: content/restored_images/R237.jpg (deflated 2%)
#   adding: content/restored_images/R2.jpg (deflated 1%)
#   adding: content/restored_images/R160.jpg (deflated 2%)
#   adding: content/restored_images/R4.jpg (deflated 2%)
#   adding: content/restored_images/R254.jpg (deflated 2%)
#   adding: content/restored_images/R35.jpg (deflated 1%)
#   adding: content/restored_images/R212.jpg (deflated 0%)
#   adding: content/restored_images/R44.jpg (deflated 1%)
#   adding: content/restored_images/R312.jpg (deflated 2%)
#   adding: content/restored_images/R71.jpg (deflated 2%)
#   adding: content/restored_images/R214.jpg (deflated 2%)
#   adding: content/restored_images/R261.jpg (deflated 3%)
#   adding: content/restored_images/R208.jpg (deflated 2%)
#   adding: content/restored_images/R142.jpg (deflated 2%)
#   adding: content/restored_images/R152.jpg (deflated 2%)
#   adding: content/restored_images/R168.jpg (deflated 2%)
#   adding: content/restored_images/R260.jpg (deflated 3%)
#   adding: content/restored_images/R124.jpg (deflated 2%)
#   adding: content/restored_images/R283.jpg (deflated 2%)
#   adding: content/restored_images/R241.jpg (deflated 2%)
#   adding: content/restored_images/R51.jpg (deflated 2%)
#   adding: content/restored_images/R224.jpg (deflated 2%)
#   adding: content/restored_images/R13.jpg (deflated 2%)
#   adding: content/restored_images/R63.jpg (deflated 2%)
#   adding: content/restored_images/R74.jpg (deflated 2%)
#   adding: content/restored_images/R301.jpg (deflated 2%)
#   adding: content/restored_images/R157.jpg (deflated 2%)
#   adding: content/restored_images/R90.jpg (deflated 2%)
#   adding: content/restored_images/R221.jpg (deflated 2%)
#   adding: content/restored_images/R273.jpg (deflated 2%)
#   adding: content/restored_images/R39.jpg (deflated 3%)
#   adding: content/restored_images/R249.jpg (deflated 2%)
#   adding: content/restored_images/R253.jpg (deflated 2%)
#   adding: content/restored_images/R259.jpg (deflated 2%)
#   adding: content/restored_images/R299.jpg (deflated 2%)
#   adding: content/restored_images/R105.jpg (deflated 2%)
#   adding: content/restored_images/R1.jpg (deflated 1%)
#   adding: content/restored_images/R123.jpg (deflated 2%)
#   adding: content/restored_images/R32.jpg (deflated 1%)
#   adding: content/restored_images/R99.jpg (deflated 2%)
#   adding: content/restored_images/R173.jpg (deflated 2%)
#   adding: content/restored_images/R48.jpg (deflated 2%)
#   adding: content/restored_images/R257.jpg (deflated 2%)
#   adding: content/restored_images/R258.jpg (deflated 3%)
#   adding: content/restored_images/R262.jpg (deflated 2%)
#   adding: content/restored_images/R114.jpg (deflated 2%)
#   adding: content/restored_images/R296.jpg (deflated 2%)
#   adding: content/restored_images/R27.jpg (deflated 1%)
#   adding: content/restored_images/R198.jpg (deflated 2%)
#   adding: content/restored_images/R135.jpg (deflated 2%)
#   adding: content/restored_images/R326.jpg (deflated 0%)
#   adding: content/restored_images/R291.jpg (deflated 2%)
#   adding: content/restored_images/R11.jpg (deflated 2%)
#   adding: content/restored_images/R304.jpg (deflated 2%)
#   adding: content/restored_images/R169.jpg (deflated 2%)
#   adding: content/restored_images/R37.jpg (deflated 1%)
#   adding: content/restored_images/R327.jpg (deflated 0%)
#   adding: content/restored_images/R203.jpg (deflated 2%)
#   adding: content/restored_images/R5.jpg (deflated 0%)
#   adding: content/restored_images/R181.jpg (deflated 2%)
#   adding: content/restored_images/R92.jpg (deflated 2%)
#   adding: content/restored_images/R256.jpg (deflated 2%)
#   adding: content/restored_images/R251.jpg (deflated 3%)
#   adding: content/restored_images/R42.jpg (deflated 2%)
#   adding: content/restored_images/R308.jpg (deflated 3%)
#   adding: content/restored_images/R268.jpg (deflated 2%)
#   adding: content/restored_images/R82.jpg (deflated 2%)
#   adding: content/restored_images/R217.jpg (deflated 2%)
#   adding: content/restored_images/R33.jpg (deflated 0%)
#   adding: content/restored_images/R202.jpg (deflated 2%)
#   adding: content/restored_images/R150.jpg (deflated 2%)
#   adding: content/restored_images/R245.jpg (deflated 3%)
#   adding: content/restored_images/R222.jpg (deflated 2%)
#   adding: content/restored_images/R101.jpg (deflated 2%)
#   adding: content/restored_images/R76.jpg (deflated 3%)
#   adding: content/restored_images/R179.jpg (deflated 3%)
#   adding: content/restored_images/R75.jpg (deflated 4%)
#   adding: content/restored_images/R307.jpg (deflated 2%)
#   adding: content/restored_images/R178.jpg (deflated 2%)
#   adding: content/restored_images/R104.jpg (deflated 2%)
#   adding: content/restored_images/R94.jpg (deflated 2%)
#   adding: content/restored_images/R59.jpg (deflated 2%)
#   adding: content/restored_images/R110.jpg (deflated 2%)
#   adding: content/restored_images/R12.jpg (deflated 2%)
#   adding: content/restored_images/R80.jpg (deflated 2%)
#   adding: content/restored_images/R176.jpg (deflated 2%)
#   adding: content/restored_images/R107.jpg (deflated 2%)
#   adding: content/restored_images/R9.jpg (deflated 2%)
#   adding: content/restored_images/R219.jpg (deflated 2%)
#   adding: content/restored_images/R223.jpg (deflated 2%)
#   adding: content/restored_images/R148.jpg (deflated 2%)
#   adding: content/restored_images/R127.jpg (deflated 2%)
#   adding: content/restored_images/R282.jpg (deflated 2%)
#   adding: content/restored_images/R195.jpg (deflated 2%)
#   adding: content/restored_images/R31.jpg (deflated 0%)
#   adding: content/restored_images/R126.jpg (deflated 2%)
#   adding: content/restored_images/R130.jpg (deflated 2%)
#   adding: content/restored_images/R121.jpg (deflated 2%)
#   adding: content/restored_images/R54.jpg (deflated 16%)
#   adding: content/restored_images/R285.jpg (deflated 3%)
#   adding: content/restored_images/R156.jpg (deflated 2%)
#   adding: content/restored_images/R100.jpg (deflated 2%)
#   adding: content/restored_images/R8.jpg (deflated 3%)
#   adding: content/restored_images/R164.jpg (deflated 2%)
#   adding: content/restored_images/R120.jpg (deflated 2%)
#   adding: content/restored_images/R320.jpg (deflated 1%)
#   adding: content/restored_images/R125.jpg (deflated 2%)
#   adding: content/restored_images/R300.jpg (deflated 2%)
#   adding: content/restored_images/R140.jpg (deflated 2%)
#   adding: content/restored_images/R45.jpg (deflated 2%)
#   adding: content/restored_images/R229.jpg (deflated 2%)
#   adding: content/restored_images/R68.jpg (deflated 2%)
#   adding: content/restored_images/R29.jpg (deflated 1%)
#   adding: content/restored_images/R53.jpg (deflated 2%)
#   adding: content/restored_images/R28.jpg (deflated 0%)
#   adding: content/restored_images/R47.jpg (deflated 17%)
#   adding: content/restored_images/R170.jpg (deflated 2%)
#   adding: content/restored_images/R153.jpg (deflated 2%)
#   adding: content/restored_images/R189.jpg (deflated 2%)
#   adding: content/restored_images/R50.jpg (deflated 2%)
#   adding: content/restored_images/R228.jpg (deflated 2%)
#   adding: content/restored_images/R86.jpg (deflated 3%)
#   adding: content/restored_images/R87.jpg (deflated 3%)
#   adding: content/restored_images/R67.jpg (deflated 3%)
#   adding: content/restored_images/R321.jpg (deflated 1%)
#   adding: content/restored_images/R66.jpg (deflated 2%)
#   adding: content/restored_images/R134.jpg (deflated 3%)
#   adding: content/restored_images/R109.jpg (deflated 2%)
#   adding: content/restored_images/R145.jpg (deflated 2%)
#   adding: content/restored_images/R177.jpg (deflated 2%)
#   adding: content/restored_images/R165.jpg (deflated 3%)
#   adding: content/restored_images/R314.jpg (deflated 3%)
#   adding: content/restored_images/R84.jpg (deflated 2%)
#   adding: content/restored_images/R197.jpg (deflated 3%)
#   adding: content/restored_images/R297.jpg (deflated 2%)
#   adding: content/restored_images/R149.jpg (deflated 3%)
#   adding: content/restored_images/R274.jpg (deflated 2%)
#   adding: content/restored_images/R200.jpg (deflated 2%)
#   adding: content/restored_images/R98.jpg (deflated 2%)
#   adding: content/restored_images/R143.jpg (deflated 2%)
#   adding: content/restored_images/R187.jpg (deflated 2%)
#   adding: content/restored_images/R315.jpg (deflated 3%)
#   adding: content/restored_images/R207.jpg (deflated 2%)
#   adding: content/restored_images/R284.jpg (deflated 3%)
#   adding: content/restored_images/R239.jpg (deflated 2%)
#   adding: content/restored_images/R79.jpg (deflated 2%)
#   adding: content/restored_images/R95.jpg (deflated 3%)
#   adding: content/restored_images/R103.jpg (deflated 3%)
#   adding: content/restored_images/R147.jpg (deflated 3%)
#   adding: content/restored_images/R131.jpg (deflated 3%)
#   adding: content/restored_images/R77.jpg (deflated 3%)
#   adding: content/restored_images/R236.jpg (deflated 2%)
#   adding: content/restored_images/R215.jpg (deflated 2%)
#   adding: content/restored_images/R18.jpg (deflated 1%)
#   adding: content/restored_images/R162.jpg (deflated 2%)

# %% [markdown]
# another api url to get photographs collected by PHOTOCONSORTIUM

# %%
import os
import requests
from urllib.parse import urlparse, parse_qs
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Set up the folder to store images on your local machine
folder_name = "restored_images1"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Parse the provided URL to extract the base URL and query parameters
api_url = "https://api.europeana.eu/record/search.json?wskey=hylepsentrog&qf=collection%3Aphotography&qf=TYPE%3A%22IMAGE%22&qf=contentTier%3A%224%22&qf=PROVIDER%3A%22PHOTOCONSORTIUM%22&query=places&reusability=open&profile=facets&rows=0&facet=REUSABILITY&start=1"

# Parse the URL
parsed_url = urlparse(api_url)
base_url = f"{parsed_url.scheme}://{parsed_url.netloc}{parsed_url.path}"
params = parse_qs(parsed_url.query)

# Convert the list of query values to a single value where appropriate
for key in params:
    if isinstance(params[key], list) and len(params[key]) == 1:
        params[key] = params[key][0]

# Set rows to a specific value to get actual data (instead of 0)
params['rows'] = 100  # Adjust this as needed

# Function to download an image
def download_image(url, image_name):
    if isinstance(url, list):
        url = url[0]  # Extract the string from the list if needed

    session = requests.Session()
    retries = Retry(total=5, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
    session.mount('https://', HTTPAdapter(max_retries=retries))
    session.mount('http://', HTTPAdapter(max_retries=retries))

    try:
        # Disable SSL verification if needed
        img_response = session.get(url, verify=False)
        if img_response.status_code == 200:
            # Save the image to the local "restored_images" folder
            with open(os.path.join(folder_name, image_name), 'wb') as img_file:
                img_file.write(img_response.content)
            print(f"Downloaded {image_name}")
        elif img_response.status_code == 404:
            print(f"Image not found (404) for {image_name}")
        else:
            print(f"Failed to download {image_name}, status code: {img_response.status_code}")
    except requests.exceptions.SSLError as e:
        print(f"SSL error occurred while downloading {image_name}: {e}")
    except requests.exceptions.RequestException as e:
        print(f"Request error occurred while downloading {image_name}: {e}")

# Fetch and process the data from the API
image_count = 0
while True:
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])

        # Download each image
        for item in items:
            if 'edmIsShownBy' in item:
                img_url = item['edmIsShownBy']
                download_image(img_url, f"R{image_count}.jpg")
                image_count += 1

        # Check if there are more results to fetch
        if len(items) < int(params['rows']):
            break  # Exit the loop if fewer items are returned than requested (end of results)
        else:
            params['start'] = int(params['start']) + int(params['rows'])  # Move to the next page
    else:
        print(f"Failed to retrieve data from the API. Status code: {response.status_code}")
        break
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R0.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R1.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R2.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R3.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R4.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R5.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R6.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R7.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R8.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R9.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R10.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R11.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R12.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R13.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R14.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R15.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R16.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R17.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R18.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R19.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R20.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R21.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R22.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R23.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R24.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R25.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R26.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R27.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R28.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R29.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R30.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R31.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R32.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R33.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R34.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R35.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R36.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R37.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R38.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R39.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R40.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R41.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R42.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R43.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R44.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R45.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R46.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R47.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R48.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R49.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R50.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R51.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R52.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R53.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R54.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R55.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R56.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R57.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R58.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R59.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R60.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R61.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R62.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R63.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R64.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R65.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R66.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R67.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R68.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R69.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R70.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R71.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R72.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R73.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R74.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R75.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R76.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R77.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R78.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R79.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R80.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R81.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R82.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R83.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R84.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R85.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R86.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R87.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R88.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R89.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R90.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R91.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R92.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R93.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R94.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R95.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R96.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R97.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R98.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R99.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R100.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R101.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R102.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R103.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R104.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R105.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R106.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R107.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R108.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R109.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R110.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R111.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R112.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R113.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R114.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R115.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R116.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R117.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R118.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R119.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R120.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R121.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R122.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R123.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R124.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R125.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R126.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R127.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R128.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R129.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R130.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R131.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R132.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R133.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R134.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R135.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R136.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R137.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R138.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R139.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R140.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R141.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R142.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R143.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
# ...
#   warnings.warn(
# Downloaded R243.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R244.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R245.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R246.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R247.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R248.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R249.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R250.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R251.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R252.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R253.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R254.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R255.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R256.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R257.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R258.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R259.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R260.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R261.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R262.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R263.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R264.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R265.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R266.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R267.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R268.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R269.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R270.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R271.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R272.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R273.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R274.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R275.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R276.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R277.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R278.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R279.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R280.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R281.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R282.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R283.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R284.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R285.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R286.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R287.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R288.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R289.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R290.jpg
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sgdap.girona.cat'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloaded R291.jpg

# %%
from google.colab import files
# !zip -r /content/restored_images1.zip /content/restored_images1
files.download("/content/restored_images1.zip")
# Out:
#   adding: content/restored_images1/ (stored 0%)
#   adding: content/restored_images1/R81.jpg (deflated 5%)
#   adding: content/restored_images1/R267.jpg (deflated 4%)
#   adding: content/restored_images1/R246.jpg (deflated 8%)
#   adding: content/restored_images1/R56.jpg (deflated 4%)
#   adding: content/restored_images1/R167.jpg (deflated 3%)
#   adding: content/restored_images1/R69.jpg (deflated 5%)
#   adding: content/restored_images1/R277.jpg (deflated 3%)
#   adding: content/restored_images1/R38.jpg (deflated 4%)
#   adding: content/restored_images1/R117.jpg (deflated 8%)
#   adding: content/restored_images1/R15.jpg (deflated 7%)
#   adding: content/restored_images1/R112.jpg (deflated 9%)
#   adding: content/restored_images1/R155.jpg (deflated 9%)
#   adding: content/restored_images1/R172.jpg (deflated 3%)
#   adding: content/restored_images1/R119.jpg (deflated 4%)
#   adding: content/restored_images1/R83.jpg (deflated 6%)
#   adding: content/restored_images1/R25.jpg (deflated 6%)
#   adding: content/restored_images1/R231.jpg (deflated 5%)
#   adding: content/restored_images1/R230.jpg (deflated 7%)
#   adding: content/restored_images1/R52.jpg (deflated 4%)
#   adding: content/restored_images1/R266.jpg (deflated 5%)
#   adding: content/restored_images1/R88.jpg (deflated 4%)
#   adding: content/restored_images1/R186.jpg (deflated 7%)
#   adding: content/restored_images1/R192.jpg (deflated 3%)
#   adding: content/restored_images1/R289.jpg (deflated 7%)
#   adding: content/restored_images1/R191.jpg (deflated 5%)
#   adding: content/restored_images1/R7.jpg (deflated 7%)
#   adding: content/restored_images1/R158.jpg (deflated 3%)
#   adding: content/restored_images1/R216.jpg (deflated 4%)
#   adding: content/restored_images1/R78.jpg (deflated 7%)
#   adding: content/restored_images1/R10.jpg (deflated 4%)
#   adding: content/restored_images1/R213.jpg (deflated 6%)
#   adding: content/restored_images1/R183.jpg (deflated 6%)
#   adding: content/restored_images1/R3.jpg (deflated 3%)
#   adding: content/restored_images1/R204.jpg (deflated 3%)
#   adding: content/restored_images1/R14.jpg (deflated 5%)
#   adding: content/restored_images1/R128.jpg (deflated 3%)
#   adding: content/restored_images1/R205.jpg (deflated 3%)
#   adding: content/restored_images1/R281.jpg (deflated 4%)
#   adding: content/restored_images1/R220.jpg (deflated 3%)
#   adding: content/restored_images1/R290.jpg (deflated 3%)
#   adding: content/restored_images1/R242.jpg (deflated 3%)
#   adding: content/restored_images1/R93.jpg (deflated 7%)
#   adding: content/restored_images1/R278.jpg (deflated 5%)
#   adding: content/restored_images1/R102.jpg (deflated 7%)
#   adding: content/restored_images1/R270.jpg (deflated 5%)
#   adding: content/restored_images1/R184.jpg (deflated 6%)
#   adding: content/restored_images1/R194.jpg (deflated 5%)
#   adding: content/restored_images1/R276.jpg (deflated 5%)
#   adding: content/restored_images1/R233.jpg (deflated 4%)
#   adding: content/restored_images1/R40.jpg (deflated 4%)
#   adding: content/restored_images1/R248.jpg (deflated 3%)
#   adding: content/restored_images1/R146.jpg (deflated 3%)
#   adding: content/restored_images1/R138.jpg (deflated 13%)
#   adding: content/restored_images1/R55.jpg (deflated 6%)
#   adding: content/restored_images1/R41.jpg (deflated 2%)
#   adding: content/restored_images1/R34.jpg (deflated 12%)
#   adding: content/restored_images1/R193.jpg (deflated 5%)
#   adding: content/restored_images1/R26.jpg (deflated 4%)
#   adding: content/restored_images1/R199.jpg (deflated 4%)
#   adding: content/restored_images1/R174.jpg (deflated 5%)
#   adding: content/restored_images1/R286.jpg (deflated 9%)
#   adding: content/restored_images1/R137.jpg (deflated 7%)
#   adding: content/restored_images1/R287.jpg (deflated 4%)
#   adding: content/restored_images1/R108.jpg (deflated 5%)
#   adding: content/restored_images1/R22.jpg (deflated 4%)
#   adding: content/restored_images1/R161.jpg (deflated 4%)
#   adding: content/restored_images1/R61.jpg (deflated 4%)
#   adding: content/restored_images1/R58.jpg (deflated 7%)
#   adding: content/restored_images1/R73.jpg (deflated 6%)
#   adding: content/restored_images1/R19.jpg (deflated 5%)
#   adding: content/restored_images1/R234.jpg (deflated 4%)
#   adding: content/restored_images1/R151.jpg (deflated 6%)
#   adding: content/restored_images1/R226.jpg (deflated 3%)
#   adding: content/restored_images1/R62.jpg (deflated 3%)
#   adding: content/restored_images1/R36.jpg (deflated 5%)
#   adding: content/restored_images1/R122.jpg (deflated 4%)
#   adding: content/restored_images1/R225.jpg (deflated 3%)
#   adding: content/restored_images1/R252.jpg (deflated 3%)
#   adding: content/restored_images1/R243.jpg (deflated 7%)
#   adding: content/restored_images1/R255.jpg (deflated 6%)
#   adding: content/restored_images1/R17.jpg (deflated 7%)
#   adding: content/restored_images1/R49.jpg (deflated 4%)
#   adding: content/restored_images1/R144.jpg (deflated 6%)
#   adding: content/restored_images1/R133.jpg (deflated 5%)
#   adding: content/restored_images1/R182.jpg (deflated 4%)
#   adding: content/restored_images1/R20.jpg (deflated 5%)
#   adding: content/restored_images1/R97.jpg (deflated 7%)
#   adding: content/restored_images1/R85.jpg (deflated 5%)
#   adding: content/restored_images1/R163.jpg (deflated 6%)
#   adding: content/restored_images1/R201.jpg (deflated 7%)
#   adding: content/restored_images1/R57.jpg (deflated 4%)
#   adding: content/restored_images1/R139.jpg (deflated 3%)
#   adding: content/restored_images1/R210.jpg (deflated 3%)
#   adding: content/restored_images1/R70.jpg (deflated 4%)
#   adding: content/restored_images1/R16.jpg (deflated 5%)
#   adding: content/restored_images1/R111.jpg (deflated 3%)
#   adding: content/restored_images1/R272.jpg (deflated 6%)
#   adding: content/restored_images1/R24.jpg (deflated 6%)
#   adding: content/restored_images1/R271.jpg (deflated 7%)
#   adding: content/restored_images1/R136.jpg (deflated 5%)
#   adding: content/restored_images1/R218.jpg (deflated 5%)
#   adding: content/restored_images1/R263.jpg (deflated 4%)
#   adding: content/restored_images1/R188.jpg (deflated 6%)
#   adding: content/restored_images1/R265.jpg (deflated 3%)
#   adding: content/restored_images1/R244.jpg (deflated 6%)
#   adding: content/restored_images1/R196.jpg (deflated 6%)
#   adding: content/restored_images1/R64.jpg (deflated 4%)
#   adding: content/restored_images1/R6.jpg (deflated 9%)
#   adding: content/restored_images1/R0.jpg (deflated 3%)
#   adding: content/restored_images1/R159.jpg (deflated 3%)
#   adding: content/restored_images1/R65.jpg (deflated 4%)
#   adding: content/restored_images1/R115.jpg (deflated 6%)
#   adding: content/restored_images1/R275.jpg (deflated 6%)
#   adding: content/restored_images1/R72.jpg (deflated 3%)
#   adding: content/restored_images1/R175.jpg (deflated 7%)
#   adding: content/restored_images1/R106.jpg (deflated 7%)
#   adding: content/restored_images1/R116.jpg (deflated 6%)
#   adding: content/restored_images1/R185.jpg (deflated 5%)
#   adding: content/restored_images1/R209.jpg (deflated 3%)
#   adding: content/restored_images1/R129.jpg (deflated 8%)
#   adding: content/restored_images1/R264.jpg (deflated 5%)
#   adding: content/restored_images1/R288.jpg (deflated 5%)
#   adding: content/restored_images1/R250.jpg (deflated 4%)
#   adding: content/restored_images1/R232.jpg (deflated 8%)
#   adding: content/restored_images1/R89.jpg (deflated 5%)
#   adding: content/restored_images1/R132.jpg (deflated 4%)
#   adding: content/restored_images1/R118.jpg (deflated 2%)
#   adding: content/restored_images1/R141.jpg (deflated 4%)
#   adding: content/restored_images1/R171.jpg (deflated 4%)
#   adding: content/restored_images1/R30.jpg (deflated 4%)
#   adding: content/restored_images1/R227.jpg (deflated 3%)
#   adding: content/restored_images1/R269.jpg (deflated 3%)
#   adding: content/restored_images1/R280.jpg (deflated 4%)
#   adding: content/restored_images1/R46.jpg (deflated 4%)
#   adding: content/restored_images1/R23.jpg (deflated 12%)
#   adding: content/restored_images1/R206.jpg (deflated 4%)
#   adding: content/restored_images1/R60.jpg (deflated 4%)
#   adding: content/restored_images1/R240.jpg (deflated 5%)
#   adding: content/restored_images1/R211.jpg (deflated 6%)
#   adding: content/restored_images1/R279.jpg (deflated 6%)
#   adding: content/restored_images1/R190.jpg (deflated 7%)
#   adding: content/restored_images1/R96.jpg (deflated 6%)
#   adding: content/restored_images1/R166.jpg (deflated 3%)
#   adding: content/restored_images1/R235.jpg (deflated 5%)
#   adding: content/restored_images1/R247.jpg (deflated 3%)
#   adding: content/restored_images1/R91.jpg (deflated 8%)
#   adding: content/restored_images1/R180.jpg (deflated 5%)
#   adding: content/restored_images1/R113.jpg (deflated 6%)
#   adding: content/restored_images1/R43.jpg (deflated 7%)
#   adding: content/restored_images1/R154.jpg (deflated 3%)
#   adding: content/restored_images1/R238.jpg (deflated 3%)
#   adding: content/restored_images1/R21.jpg (deflated 7%)
#   adding: content/restored_images1/R237.jpg (deflated 4%)
#   adding: content/restored_images1/R2.jpg (deflated 4%)
#   adding: content/restored_images1/R160.jpg (deflated 3%)
#   adding: content/restored_images1/R4.jpg (deflated 8%)
#   adding: content/restored_images1/R254.jpg (deflated 5%)
#   adding: content/restored_images1/R35.jpg (deflated 4%)
#   adding: content/restored_images1/R212.jpg (deflated 9%)
#   adding: content/restored_images1/R44.jpg (deflated 6%)
#   adding: content/restored_images1/R71.jpg (deflated 4%)
#   adding: content/restored_images1/R214.jpg (deflated 9%)
#   adding: content/restored_images1/R261.jpg (deflated 5%)
#   adding: content/restored_images1/R208.jpg (deflated 8%)
#   adding: content/restored_images1/R142.jpg (deflated 7%)
#   adding: content/restored_images1/R152.jpg (deflated 4%)
#   adding: content/restored_images1/R168.jpg (deflated 7%)
#   adding: content/restored_images1/R260.jpg (deflated 6%)
#   adding: content/restored_images1/R124.jpg (deflated 9%)
#   adding: content/restored_images1/R283.jpg (deflated 4%)
#   adding: content/restored_images1/R241.jpg (deflated 4%)
#   adding: content/restored_images1/R51.jpg (deflated 4%)
#   adding: content/restored_images1/R224.jpg (deflated 2%)
#   adding: content/restored_images1/R13.jpg (deflated 5%)
#   adding: content/restored_images1/R63.jpg (deflated 7%)
#   adding: content/restored_images1/R74.jpg (deflated 6%)
#   adding: content/restored_images1/R157.jpg (deflated 6%)
#   adding: content/restored_images1/R90.jpg (deflated 6%)
#   adding: content/restored_images1/R221.jpg (deflated 6%)
#   adding: content/restored_images1/R273.jpg (deflated 3%)
#   adding: content/restored_images1/R39.jpg (deflated 7%)
#   adding: content/restored_images1/R249.jpg (deflated 5%)
#   adding: content/restored_images1/R253.jpg (deflated 3%)
#   adding: content/restored_images1/R259.jpg (deflated 3%)
#   adding: content/restored_images1/R105.jpg (deflated 8%)
#   adding: content/restored_images1/R1.jpg (deflated 5%)
#   adding: content/restored_images1/R123.jpg (deflated 8%)
#   adding: content/restored_images1/R32.jpg (deflated 4%)
#   adding: content/restored_images1/R99.jpg (deflated 5%)
#   adding: content/restored_images1/R173.jpg (deflated 3%)
#   adding: content/restored_images1/R48.jpg (deflated 5%)
#   adding: content/restored_images1/R257.jpg (deflated 7%)
#   adding: content/restored_images1/R258.jpg (deflated 4%)
#   adding: content/restored_images1/R262.jpg (deflated 3%)
#   adding: content/restored_images1/R114.jpg (deflated 8%)
#   adding: content/restored_images1/R27.jpg (deflated 6%)
#   adding: content/restored_images1/R198.jpg (deflated 4%)
#   adding: content/restored_images1/R135.jpg (deflated 6%)
#   adding: content/restored_images1/R291.jpg (deflated 5%)
#   adding: content/restored_images1/R11.jpg (deflated 7%)
#   adding: content/restored_images1/R169.jpg (deflated 4%)
#   adding: content/restored_images1/R37.jpg (deflated 7%)
#   adding: content/restored_images1/R203.jpg (deflated 3%)
#   adding: content/restored_images1/R5.jpg (deflated 4%)
#   adding: content/restored_images1/R181.jpg (deflated 4%)
#   adding: content/restored_images1/R92.jpg (deflated 10%)
#   adding: content/restored_images1/R256.jpg (deflated 4%)
#   adding: content/restored_images1/R251.jpg (deflated 5%)
#   adding: content/restored_images1/R42.jpg (deflated 6%)
#   adding: content/restored_images1/R268.jpg (deflated 3%)
#   adding: content/restored_images1/R82.jpg (deflated 3%)
#   adding: content/restored_images1/R217.jpg (deflated 4%)
#   adding: content/restored_images1/R33.jpg (deflated 4%)
#   adding: content/restored_images1/R202.jpg (deflated 7%)
#   adding: content/restored_images1/R150.jpg (deflated 5%)
#   adding: content/restored_images1/R245.jpg (deflated 8%)
#   adding: content/restored_images1/R222.jpg (deflated 3%)
#   adding: content/restored_images1/R101.jpg (deflated 4%)
#   adding: content/restored_images1/R76.jpg (deflated 5%)
#   adding: content/restored_images1/R179.jpg (deflated 4%)
#   adding: content/restored_images1/R75.jpg (deflated 7%)
#   adding: content/restored_images1/R178.jpg (deflated 5%)
#   adding: content/restored_images1/R104.jpg (deflated 6%)
#   adding: content/restored_images1/R94.jpg (deflated 3%)
#   adding: content/restored_images1/R59.jpg (deflated 7%)
#   adding: content/restored_images1/R110.jpg (deflated 5%)
#   adding: content/restored_images1/R12.jpg (deflated 6%)
#   adding: content/restored_images1/R80.jpg (deflated 7%)
#   adding: content/restored_images1/R176.jpg (deflated 4%)
#   adding: content/restored_images1/R107.jpg (deflated 14%)
#   adding: content/restored_images1/R9.jpg (deflated 6%)
#   adding: content/restored_images1/R219.jpg (deflated 7%)
#   adding: content/restored_images1/R223.jpg (deflated 3%)
#   adding: content/restored_images1/R148.jpg (deflated 6%)
#   adding: content/restored_images1/R127.jpg (deflated 7%)
#   adding: content/restored_images1/R282.jpg (deflated 6%)
#   adding: content/restored_images1/R195.jpg (deflated 5%)
#   adding: content/restored_images1/R31.jpg (deflated 4%)
#   adding: content/restored_images1/R126.jpg (deflated 5%)
#   adding: content/restored_images1/R130.jpg (deflated 8%)
#   adding: content/restored_images1/R121.jpg (deflated 8%)
#   adding: content/restored_images1/R54.jpg (deflated 3%)
#   adding: content/restored_images1/R285.jpg (deflated 8%)
#   adding: content/restored_images1/R156.jpg (deflated 5%)
#   adding: content/restored_images1/R100.jpg (deflated 5%)
#   adding: content/restored_images1/R8.jpg (deflated 8%)
#   adding: content/restored_images1/R164.jpg (deflated 5%)
#   adding: content/restored_images1/R120.jpg (deflated 8%)
#   adding: content/restored_images1/R125.jpg (deflated 5%)
#   adding: content/restored_images1/R140.jpg (deflated 3%)
#   adding: content/restored_images1/R45.jpg (deflated 8%)
#   adding: content/restored_images1/R229.jpg (deflated 5%)
#   adding: content/restored_images1/R68.jpg (deflated 9%)
#   adding: content/restored_images1/R29.jpg (deflated 5%)
#   adding: content/restored_images1/R53.jpg (deflated 4%)
#   adding: content/restored_images1/R28.jpg (deflated 4%)
#   adding: content/restored_images1/R47.jpg (deflated 6%)
#   adding: content/restored_images1/R170.jpg (deflated 4%)
#   adding: content/restored_images1/R153.jpg (deflated 4%)
#   adding: content/restored_images1/R189.jpg (deflated 5%)
#   adding: content/restored_images1/R50.jpg (deflated 4%)
#   adding: content/restored_images1/R228.jpg (deflated 9%)
#   adding: content/restored_images1/R86.jpg (deflated 5%)
#   adding: content/restored_images1/R87.jpg (deflated 4%)
#   adding: content/restored_images1/R67.jpg (deflated 4%)
#   adding: content/restored_images1/R66.jpg (deflated 4%)
#   adding: content/restored_images1/R134.jpg (deflated 7%)
#   adding: content/restored_images1/R109.jpg (deflated 4%)
#   adding: content/restored_images1/R145.jpg (deflated 4%)
#   adding: content/restored_images1/R177.jpg (deflated 4%)
#   adding: content/restored_images1/R165.jpg (deflated 3%)
#   adding: content/restored_images1/R84.jpg (deflated 5%)
#   adding: content/restored_images1/R197.jpg (deflated 5%)
#   adding: content/restored_images1/R149.jpg (deflated 5%)
#   adding: content/restored_images1/R274.jpg (deflated 5%)
#   adding: content/restored_images1/R200.jpg (deflated 5%)
#   adding: content/restored_images1/R98.jpg (deflated 4%)
#   adding: content/restored_images1/R143.jpg (deflated 3%)
#   adding: content/restored_images1/R187.jpg (deflated 9%)
#   adding: content/restored_images1/R207.jpg (deflated 6%)
#   adding: content/restored_images1/R284.jpg (deflated 3%)
#   adding: content/restored_images1/R239.jpg (deflated 3%)
#   adding: content/restored_images1/R79.jpg (deflated 6%)
#   adding: content/restored_images1/R95.jpg (deflated 7%)
#   adding: content/restored_images1/R103.jpg (deflated 7%)
#   adding: content/restored_images1/R147.jpg (deflated 4%)
#   adding: content/restored_images1/R131.jpg (deflated 6%)
#   adding: content/restored_images1/R77.jpg (deflated 3%)
#   adding: content/restored_images1/R236.jpg (deflated 9%)
#   adding: content/restored_images1/R215.jpg (deflated 4%)
#   adding: content/restored_images1/R18.jpg (deflated 4%)
#   adding: content/restored_images1/R162.jpg (deflated 4%)
